# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1= int(10)
Num2= int(30)
Add= Num1+Num2
print("Num1= ",Num1)
print("Num2= ",Num2)
print("Add= ",Add)
# Out:
# Num1=  10
# Num2=  30
# Add=  40

# %%
bmi= float(input("Enter the BMI Index"))
if(bmi < 18.5):
    print("Underweight")
elif(bmi <= 24.9):
    print("Healthy Weight") 
elif(bmi<= 29.9):
    print("Overweight")
else:
    print("Very Overweight")
# Out:
# Enter the BMI Index 18.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bmi= int(input("Enter the BMI Index"))
#       2 if(bmi < 18.5):
#       3     print("Underweight")
#
# ValueError: invalid literal for int() with base 10: '18.4'
