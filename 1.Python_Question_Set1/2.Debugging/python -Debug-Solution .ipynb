# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
#: is missing after range(5)
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
#2convert to int 

a = 10
b = "5"
print(a + int(b))
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
#: missing
def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
# position starts from 0 in the list so tyring to print numbers[4], is out of the list length's position so it is invalid

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
#() missing in the print command
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
# indivisible error

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
# age is not typecasted to 
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#in range the third parameter is less than the initialized value which is less than 1, so it will not print

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
#the condition is with single = operator which is incorrect ichecked using ==
x = int(10)
if (x == 5):
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
#: is missing at the first line
