# %%
#from fileName import ClassName

from ClassForAllFunctions import AllFunctions

# %%
AllFunctions.subFields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
AllFunctions.findEvenOdd()
# Out:
# Enter a number: 36
# 36 is Even number
# 'Even number'

# %%
AllFunctions.marriageEligibility()
# Out:
# Your Gender: Female
# Your Age: 36
# ELIGIBLE
# 'ELIGIBLE'

# %%
AllFunctions.percentage()
# Out:
# Total: 473
# Percentage: 94.6
# 94.6

# %%
AllFunctions.triangle()
# Out:
# Height : 32
# Breadth : 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1 : 2
# Height2 : 4
# Breadth : 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10
