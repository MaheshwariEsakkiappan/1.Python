# %%
1. What will be the output of print(type(5)) in Python?
a) <class 'str'>
 b) <class 'int'>
 c) <class 'float'>
 d) <class 'boolean'>

Solution:  b) <class 'int'>

# %%
2. Which function is used to find the length of a string in Python?
a) length()
 b) size()
 c) len()
 d) count()

Solution: len()

# %%
3. How do you start a multiline comment in Python?
a) //
 b) /*
 c) """
 d) #

Solution: #

# %%
What will print(5 / 2) return?
a) 2
 b) 2.5
 c) 2.0
 d) Error

Solution: 2

# %%
5. Which Python keyword is used to create a loop that iterates while a condition is true?
a) for
 b) loop
 c) while
 d) iterate

Solution: while

# %%
6.What will print(2 ** 3) output?
a) 6
 b) 8
 c) 9
 d) 4

Solution: 8

# %%
7.What does ord('A') return?
a) 65
 b) 'A'
 c) ASCII value of 'A'
 d) Both a and c

Solution: 65

# %%
. What is the correct way to declare a tuple in Python?
a) [1, 2, 3]
 b) {1, 2, 3}
 c) (1, 2, 3)
 d) tuple[1, 2, 3]

Solution: c

# %%
9. Which function is used to get user input in Python?
a) read()
 b) input()
 c) get()
 d) fetch()

Solution: b

# %%
10. What will bool("False") return?
a) True
 b) False
 c) None
 d) Error

Solution: True

# %%
11. How do you check the data type of a variable x in Python?
a) type(x)
 b) checkType(x)
 c) typeof(x)
 d) getType(x)
Solution : type(x)

# %%
12. What is the result of print("Hello" + 3)?
a) Hello3
 b) Error
 c) 3Hello
 d) Hello Hello Hello
Solution: Error

# %%
13. What is the output of print(3 == 3.0)?
a) True
 b) False
 c) Error
 d) None

Solution: True

# %%
14. What will list("hello") return?
a) ['hello']
 b) ['h', 'e', 'l', 'l', 'o']
 c) (h, e, l, l, o)
 d) None of the above

Solution:  b) ['h', 'e', 'l', 'l', 'o']

# %%
 15. What will print(10 // 3) output?
a) 3.33
 b) 3
 c) 4
 d) 3.0

Solution: 3
