# %%
# Scenario: You are developing a banking application that categorizes transactions based on the amount entered.
#  Write logic to determine whether the amount is positive, negative, or zero.

amount= int(input ("Enter transaction amount: "))
if(amount >0):
    transaction ="Poistive"
elif(amount ==0):
    transaction ="Zero"
elif(amount <0):
    transaction ="Negative"
print("The transaction amount entered %d INR, is %s." % (amount,transaction))
# Out:
# Enter transaction amount:  -89
# The transaction amount entered -89 INR, is Negative.

# %%
# A digital locker requires users to enter a numerical passcode. As part of a security feature, the system checks the sum of the digits of the passcode.
#  Write logic to compute the sum of the digits of a given number.

inputNumber= input("Enter a number :")
sum=0
for i in range(0,len(inputNumber)):
    sum=sum + int((inputNumber[i]))
    i=i+1
print("The sum of the input number %s is %d" %(inputNumber,sum))
# Out:
# Enter a number : 963
# The sum of the input number 963 is 18

# %%
# Scenario: A mobile payment app uses a simple checksum validation where reversing a transaction ID helps detect fraud.
#  Write logic to take a number and return its reverse.

inputNumber= input("Enter a number :")
strReverse=''
i= int(len(inputNumber))-1
while (i>=0):
    strReverse=strReverse + inputNumber[i]
    i=i-1
print("The reverse of the input number %s is %s" %(inputNumber,strReverse))
# Out:
# Enter a number : 7896541230
# The reverse of the input number 7896541230 is 0321456987

# %%
# 4.Scenario: In a secure login system, certain features are enabled only for users with prime-numbered user IDs.
#  Write logic to check if a given number is prime.

number = int(input("Enter a number: "))
is_prime = True
if number <= 1:
    is_prime = False
else:
    for i in range(2, number):
        if number % i == 0:
            is_prime = False
            break
if is_prime:
    print(number, "is a prime number")
else:
    print(number, "is not a prime number")
# Out:
# Enter a number:  3
# 3 is a prime number

# %%
# 5.Scenario: A scientist is working on permutations and needs to calculate the factorial of numbers frequently.
#  Write logic to find the factorial of a given number using recursion.

inputNumber= int(input("Enter a number: "))
i=1
fact=1
while (i<=inputNumber):
    fact= fact *i
    i=i+1
print("The factorial of the given number %d is %d" %(inputNumber,fact))
# Out:
# Enter a number:  6
# The factorial of the given number 6 is 720

# %%
# 6.Scenario: A unique lottery system assigns ticket numbers where only Armstrong numbers win the jackpot.
#  Write logic to check whether a given number is an Armstrong number.

inputNumber = input("Enter a number: ")
power = len(inputNumber)
sum = 0
for digit in inputNumber:
    digit = int(digit)
    sum = sum + digit ** power

print("Sum =", sum)

if sum == int(inputNumber):
    print("Armstrong number")
else:
    print("Not an Armstrong number")
# Out:
# Enter a number:  9474
# Sum = 9474
# Armstrong number

# %%
# A password manager needs to strengthen weak passwords by swapping the first and last characters of user-generated passwords.
#  Write logic to perform this operation on a given string.

inputPassword=input("Enter user password: ")
firstChar=inputPassword[0]
lastChar=inputPassword[(len(inputPassword)-1)]
# print(firstChar)
# print(lastChar)
newPassword=lastChar+inputPassword[1:-1]+firstChar
print(newPassword)
# Out:
# Enter user password:  Maheshwari
# iaheshwarM

# %%
# 8.Scenario: A low-level networking application requires decimal numbers to be converted into binary format before transmission.
#  Write logic to convert a given decimal number into its binary equivalent.
decimalNum= int(input("Enter decimal number: "))
binary=""
while decimalNum>0:
    reminder=decimalNum%2
    binary=str(reminder)+binary
    decimalNum=decimalNum//2

print("Binary Number:",binary )
# Out:
# Enter decimal number:  10
# Binary Number: 1010

# %%
# 9.	Scenario: A text-processing tool helps summarize articles by identifying the most significant words.
#  Write logic to find the longest word in a sentence.
statement= input("Enter your statement: ")
words = statement.split()
longestWord= ""
for word in words:
    if len(word) > len(longestWord):
        longestWord=word
print("The Longest Word is:",longestWord)
# Out:
# Enter your statement:  My name is Maheshwari
# The Longest Word is: Maheshwari

# %%
# 10.	Scenario: A plagiarism detection tool compares words from different documents and checks if they are anagrams (same characters but different order).
#  Write logic to check whether two given strings are anagrams.

first_word= input("Enter your first word: ")
second_word= input("Enter your second word: ")
if(len(first_word) != len(second_word)):
    print("Not anagrams")
first_word= first_word.lower()
second_word= second_word.lower()
if(sorted(first_word) == sorted(second_word)):
    print("Anagrams")
else:
    print("Not anagrams")
# Out:
# Enter your first word:  Below
# Enter your second word:  Elbow
# Anagrams
