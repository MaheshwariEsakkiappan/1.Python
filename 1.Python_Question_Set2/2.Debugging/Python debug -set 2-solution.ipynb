# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))

##- M is capital. Python is case sensitive

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()
## x is not initialized
# Out:
# 5

# %%
#3.x = 5
if x = 10:
    print("x is 10")

## only single = operator is used for condition checking, this is incorrect it should be ==

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

it will not print, because numbers.sort() is inbuilt and will sort the numbers and keep it in number variable itself

# %%
#5.
def square(n):
    n * n

print(square(4))

# there is no return statement as well as there is no print statement inside the function. So it will not print anything

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5

#in tuple we cannot change the value

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

## in % d str(age) is missing

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# if aa is b is incorrect is should be a==b

# %%
#9.
for i in range(5, 1):
    print(i)

# range cannot be decremented as it can only be incremented

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])

## key is not defined, the key should be defined to get the output
