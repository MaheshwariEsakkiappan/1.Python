# %%
age= int(input("Please enter your age:"))
if(age>19):
    print("You are an adult")
else:
    print("You are a minor")
# Out:
# Please enter your age: 56
# You are an adult

# %%
inputAge= int(input("Please enter your age:"))
if(inputAge<=18):
    print("Children")
elif(inputAge<=35):
    print("Adult")
elif(inputAge<=59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Please enter your age: 60
# Senior Citizen

# %%
lists=[23,56,89,78,45]

# %%
for temp in lists:
    print(temp)
# Out:
# 23
# 56
# 89
# 78
# 45

# %%
for inputAge in lists:
    if(inputAge<=18):
        print("Children")
    elif(inputAge<=35):
        print("Adult")
    elif(inputAge<=59):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Adult
# Citizen
# Senior Citizen
# Senior Citizen
# Citizen

# %%
Number= int(input("Enter number of your choice:"))
if(Number%2==0):
    print("Entered number",Number,"is Even" )
else:
    print("Entered number",Number,"is Odd" )
# Out:
# Enter number of your choice: 89
# Entered number 89 is Odd
